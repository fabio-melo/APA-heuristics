# %%
# %run tests.py

# %%
a = multifit(file='pareto.txt',taxrate=10,verbose=True)

# %%
b = nbhood(a,taxrate=10,verbose=True)

# %%
c = vnd(b, taxrate=10,verbose=True)

# %%
tx = 40
d = vnd(nbhood(multifit(file='random.txt',taxrate=tx,verbose=True),taxrate=tx,verbose=True),taxrate=tx,verbose=True)

# %%
tx = 10
d = vnd(nbhood(multifit(file='random2.txt',taxrate=tx,verbose=True),taxrate=tx,verbose=True),taxrate=tx,verbose=True)

# %%
tx = 20 
e = smarter_vnd(nbhood(multifit(file='random2.txt',taxrate=tx,verbose=True),taxrate=tx,verbose=True,meta=True),taxrate=tx,verbose=True)
# Out:
# Itens: Valor: 10236 Tamanho:97594 Taxa: 20
# 7588 151 :avoidtaxes,True
# 7593 146 :repack,shuffle,23/avoidtaxes,True
# 7593 146 :repack,shuffle,76/avoidtaxes,True
# 7592 150 :repack,unordered,23/avoidtaxes,True
# 7592 146 :repack,shuffle,139/avoidtaxes,True
# 7591 148 :repack,unordered,85/avoidtaxes,True
# Melhor Resultado da Vizinhança
# 7593 146 :repack,shuffle,23/avoidtaxes,True
# > Visitando Vizinhança 1
# 7602 144 :repack,shuffle,104/avoidtaxes,True
# 7598 145 :repack,unordered,32/avoidtaxes,True
# 7598 145 :repack,unordered,67/avoidtaxes,True
# 7598 145 :repack,unordered,68/avoidtaxes,True
# 7598 145 :repack,unordered,69/avoidtaxes,True
# Melhor Resultado da Vizinhança
# 7602 144 :repack,shuffle,104/avoidtaxes,True
# > Visitando Vizinhança 2
# 7612 142 :repack,unordered,30/avoidtaxes,True
# 7612 142 :repack,unordered,42/avoidtaxes,True
# 7612 142 :repack,unordered,108/avoidtaxes,True
# 7611 142 :repack,shuffle,44/avoidtaxes,True
# 7611 142 :repack,shuffle,95/avoidtaxes,True
# ...

# %%
f = smarter_vnd(e, taxrate=20, verbose=True)
